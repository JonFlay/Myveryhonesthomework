# %%
from rich import print

# %%
name = input("wanna make it BIG???: ")
print(name.upper())
# Out:
# BIG

# %%
name = input("Enter your name: ")

print(f"[bold green]Hello[/bold green] [italic pink1]{name}~![/italic pink1]")
# Out:
# Hello small~!
