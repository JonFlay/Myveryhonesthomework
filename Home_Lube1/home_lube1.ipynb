# %%
print("Hello, Kowalski.")

messages = ["Дружище, не хотел бы ты сняться в кино?\n", 
            "А теперь нормальным языком, по новой.\n",
            "А вот, например, кем? Халком или Локи? А?!\n",
            "А сколько у тебя бицепс в обхвате?\n", 
            "Маловат, Чебурашка!\n",
            "Ты вообще человек? А, в смысле, принят!\n",
            "А вот ты кого больше любишь маму или папу?\n",
            "Пойди и скажи это папе.\n",
            "Ну и в попу тебя.\n"
            ]

print(messages[0])
answer = str(input())
if answer == "Да":
    print(messages[2])
    answer = str(input())
    if answer == "Халком":
        print(messages[3])
        answer = int(input())
        if int(answer) >= 180:
            print(messages[5])
        elif int(answer) < 180:
            print(messages[4])
        else:
            print(messages[1])
    elif answer == "Локи":
        print(messages[6])
        answer = str(input())
        if answer == "Папу":
            print(messages[4])
        elif answer == "Маму":
            print(messages[7])
        else:
            print(messages[1])
    else:
        print(messages[1])
elif answer == "Нет":
    print(messages[8])
else:
    print(messages[1])
# Out:
# Hello, Kowalski.
# Дружище, не хотел бы ты сняться в кино?
#
# А вот, например, кем? Халком или Локи? А?!
#
# А вот ты кого больше любишь маму или папу?
#
# Пойди и скажи это папе.
